# %%
import pandas as pd

# %%
from sqlite3 import connect
conn = connect(':memory:')

# %%
df = pd.read_sql("test.db",conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Desktop\Jaypatel36\env\Lib\site-packages\pandas\io\sql.py:2202, in SQLiteDatabase.execute(self, sql, params)
#    2201 try:
# -> 2202     cur.execute(sql, *args)
#    2203     return cur
#
# OperationalError: near "test": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df = pd.read_sql("test.db",conn)
#
# File ~\Desktop\Jaypatel36\env\Lib\site-packages\pandas\io\sql.py:635, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     633 with pandasSQL_builder(con) as pandas_sql:
#     634     if isinstance(pandas_sql, SQLiteDatabase):
# --> 635         return pandas_sql.read_query(
#     636             sql,
# ...

# %%
import csv

# %%
with open("test.db", 'r') as file:
  csvreader = csv.reader(file)
  for row in csvreader:
    print(row)
# Out:
# ['SQLite format 3\x00\x10\x00\x01\x01\x00@  .[4']
# ...
